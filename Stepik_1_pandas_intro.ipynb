# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Get info about dataset

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
df.iloc[:7]

# %%
df.loc[:7]

# %%
df.head(7)

# %%
df.iloc[0:7]

# %%
df.tail(7)

# %%
df.loc[:6]

# %%
df.loc[[i for i in range(7)]]

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Executor      object
# Type          object
# Salary         int64
# dtype: object

# %%
df.shape
# Out:
# (50, 4)

# %%
df.size

# %%
df.index

# %%
df

# %%
df.columns

# %%
df.dtypes.value_counts()

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
df

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info

# %%
df.dtypes.value_counts()
# Out:
# object    5
# int64     3
# dtype: int64

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Query. Data Filter

# %%
df.loc[&['parental level of education','lunch']]
# Out:
#   File "<ipython-input-308-6105f44217c4>", line 1
#     df.loc[&['parental level of education','lunch']]
#            ^
# SyntaxError: invalid syntax

# %%
mean_writing_score=df['writing score'].mean()

# %%
df[df['writing score'] > mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[df['writing score'] > 30 & (df.gender == 'male')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Подсчет количества

# %%
df.value_counts(df.lunch=='free/reduced')\
/(df.value_counts(df.lunch=='free/reduced')+df.value_counts(df.lunch=='standard'))

# %%
df.lunch.value_counts(normalize=True)
# Out:
# standard        0.645
# free/reduced    0.355
# Name: lunch, dtype: float64

# %%
(df['race/ethnicity']=='group C').mean()
# Out:
# 0.319

# %% [markdown]
# # Задача: У какой доли студентов из датасэта в колонке lunch указано free/reduced? Формат ответа десятичная дробь, например, 0.25

# %%
(df.lunch=='free/reduced').mean()
# Out:
# 0.355

# %% [markdown]
# # Задача: Как различается среднее и дисперсия оценок по предметам у групп студентов со стандартным или урезанным ланчем?

# %%
df.loc[df['lunch']=='free/reduced',['math score','reading score','writing score']].mean()
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
df.loc[df['lunch']=='standard'].describe()-df.loc[df['lunch']=='free/reduced'].describe()
# Out:
#        math score  reading score  writing score
# count  290.000000     290.000000     290.000000
# mean    11.112982       7.000742       7.800721
# std     -1.506455      -1.064737      -1.094336
# min     19.000000       9.000000      12.000000
# 25%     12.000000       7.000000       9.000000
# 50%      9.000000       7.000000       8.000000
# 75%     11.000000       7.000000       7.000000
# max      0.000000       0.000000       0.000000

# %%
df.loc[df['lunch']=='standard'].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %% [markdown]
# ## Describe

# %%
df.loc[df['lunch']=='free/reduced'].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
df.loc[df['lunch']=='free/reduced'].mean()
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
df.loc[df['lunch']=='free/reduced'].var()
# Out:
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
df.loc[df['lunch']=='standard'].mean()
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
df.loc[df['lunch']=='standard'].var()
# Out:
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64

# %% [markdown]
# ## Избавляемся от пробелов в колонках

# %%
df.columns = [x.replace(" ", "_") for x in students_performance.columns]

# %% [markdown]
# ## Query

# %%
df.query("lunch=='standard'&test_preparation_course=='completed'")
# Out:
#      gender race/ethnicity parental_level_of_education     lunch  \
# 1    female        group C                some college  standard
# 6    female        group B                some college  standard
# 13     male        group A                some college  standard
# 35     male        group E          associate's degree  standard
# 46   female        group A          associate's degree  standard
# ..      ...            ...                         ...       ...
# 983  female        group A                some college  standard
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 1                 completed          69             90             88
# ...

# %%
df[df['parental_level_of_education'].isin(["bachelor's_degree", "master's_degree"])]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental_level_of_education, lunch, test_preparation_course, math_score, reading_score, writing_score]
# Index: []

# %% [markdown]
# ## Выборка колонок , метод .filter, like

# %%
df.filter(like ='0', axis=0)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 10     male        group C          associate's degree      standard
# 20     male        group D                 high school      standard
# 30   female        group D                some college      standard
# 40     male        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 950    male        group E                 high school      standard
# 960  female        group A                some college      standard
# 970  female        group D           bachelor's degree      standard
# 980  female        group B                 high school  free/reduced
# 990    male        group E                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.filter(like= 'score').filter(items = (i for i in range(len(df)) if i % 2 == 0), axis = 0)
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 2            90             95             93
# 4            76             78             75
# 6            88             95             92
# 8            64             64             67
# ..          ...            ...            ...
# 990          86             81             75
# 992          55             76             76
# 994          63             63             62
# 996          62             55             55
# 998          68             78             77
#
# [500 rows x 3 columns]

# %% [markdown]
# ### Просуммировать колонки

# %%
df.filter(like = 'score').sum(axis=1)
# Out:
# 0      441.384495
# 1      499.509388
# 2      561.627621
# 3      300.997212
# 4      463.433722
#           ...
# 995    569.641907
# 996    349.147494
# 997    395.273000
# 998    451.407172
# 999    503.517453
# Length: 1000, dtype: float64

# %% [markdown]
# # Группировка метод .groupby

# %%
df.groupby('gender', as_index=False)\
     .aggregate({'math_score':'mean','reading_score': 'mean'})\
     .rename(columns={'math_score':'mean_math_score','reading_score':'mean_reading_score'})
# Out:
#    gender  mean_math_score  mean_reading_score
# 0  female        63.633205           72.608108
# 1    male        68.728216           65.473029

# %%
df.groupby('gender', as_index=False)\
.aggregate({'math_score': ['mean', 'count', 'std'],'reading_score': ['std', 'min', 'max']})
# Out:
#    gender math_score                  reading_score
#                 mean count        std           std min  max
# 0  female  63.633205   518  15.491453     14.378245  17  100
# 1    male  68.728216   482  14.356277     13.931832  23  100

# %% [markdown]
# ## Группировка по-нескольким колонкам!

# %%
df.groupby(['gender','race/ethnicity'], as_index=False)\
     .aggregate({'math_score':'mean','reading_score': 'mean'})\
     .rename(columns={'math_score':'mean_math_score','reading_score':'mean_reading_score'})
# Out:
#    gender race/ethnicity  mean_math_score  mean_reading_score
# 0  female        group A        58.527778           69.000000
# 1  female        group B        61.403846           71.076923
# 2  female        group C        62.033333           71.944444
# 3  female        group D        65.248062           74.046512
# 4  female        group E        70.811594           75.840580
# 5    male        group A        63.735849           61.735849
# 6    male        group B        65.930233           62.848837
# 7    male        group C        67.611511           65.424460
# 8    male        group D        69.413534           66.135338
# 9    male        group E        76.746479           70.295775

# %% [markdown]
# ### Уникальные .unique, .nunique

# %%
df.math_score.unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8])

# %%
df.math_score.nunique()
# Out:
# 81

# %%
df.groupby(['gender','race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %% [markdown]
# ### Получить Top 5

# %%
df.sort_values(['gender','math_score'],ascending=False)\
        .groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %% [markdown]
# ## Создание и удаление колонок

# %%
df['total_score']=df.math_score+df.reading_score+df.writing_score

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %% [markdown]
# ### Создание нескольких колонок (метод .assign)

# %%
df=df.assign(total_score_log=np.log(df.total_score))

# %% [markdown]
# ### Удаление .drop

# %%
#inplace=True чтобы удалить в существующем датафрейме
df.drop('total_score_log', axis=1,inplace=True)

# %% [markdown]
# ### Просуммировать несколько колонок

# %%
df.filter(like = 'score').sum(axis=1)
# Out:
# 0      436
# 1      494
# 2      556
# 3      296
# 4      458
#       ...
# 995    564
# 996    344
# 997    390
# 998    446
# 999    498
# Length: 1000, dtype: int64

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %% [markdown]
# ### Задача. Пересчитаем число ног у героев игры Dota2! Сгруппируйте героев из датасэта по числу их ног (колонка legs), и заполните их число в задании ниже.Данные взяты отсюда, на этом же сайте можно найти больше разнообразных данных по Dota2.

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
df.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
df[df['legs']==8].describe()
# Out:
#        Unnamed: 0    id  legs
# count         1.0   1.0   1.0
# mean         59.0  61.0   8.0
# std           NaN   NaN   NaN
# min          59.0  61.0   8.0
# 25%          59.0  61.0   8.0
# 50%          59.0  61.0   8.0
# 75%          59.0  61.0   8.0
# max          59.0  61.0   8.0

# %%
df.value_counts(df.legs==2)
# Out:
# legs
# True     95
# False    22
# dtype: int64

# %% [markdown]
# ### Задача. К нам поступили данные из бухгалтерии о заработках Лупы и Пупы за разные задачи! Посмотрите у кого из них больше средний заработок в различных категориях (колонка Type) и заполните таблицу,  указывая исполнителя с большим заработком в каждой из категорий.

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')

# %%
df.groupby(['Executor','Type'], as_index=False).mean()
# Out:
#    Executor Type  Unnamed: 0      Salary
# 0     Loopa    A   46.000000   58.000000
# 1     Loopa    B   24.000000  145.166667
# 2     Loopa    C   31.666667  154.333333
# 3     Loopa    D   31.857143  137.714286
# 4     Loopa    E   23.500000  164.000000
# 5     Loopa    F   20.000000  238.000000
# 6      Pupa    A   16.000000  160.833333
# 7      Pupa    B   41.000000   77.000000
# 8      Pupa    C   23.000000   74.500000
# 9      Pupa    D   14.000000  146.500000
# 10     Pupa    E   19.800000  131.200000
# 11     Pupa    F   25.750000  136.250000

# %%
df.groupby(['Executor', 'Type'], as_index=False).aggregate({'Salary': 'mean'})
# Out:
#    Executor Type      Salary
# 0     Loopa    A   58.000000
# 1     Loopa    B  145.166667
# 2     Loopa    C  154.333333
# 3     Loopa    D  137.714286
# 4     Loopa    E  164.000000
# 5     Loopa    F  238.000000
# 6      Pupa    A  160.833333
# 7      Pupa    B   77.000000
# 8      Pupa    C   74.500000
# 9      Pupa    D  146.500000
# 10     Pupa    E  131.200000
# 11     Pupa    F  136.250000

# %%
#Наибольший для каждого типа
df.groupby(['Type', 'Executor'], as_index=False)\
.mean().sort_values(['Type','Salary'], ascending=False).groupby('Type').head(1)
# Out:
#    Type Executor  Unnamed: 0      Salary
# 10    F    Loopa   20.000000  238.000000
# 8     E    Loopa   23.500000  164.000000
# 7     D     Pupa   14.000000  146.500000
# 4     C    Loopa   31.666667  154.333333
# 2     B    Loopa   24.000000  145.166667
# 1     A     Pupa   16.000000  160.833333

# %% [markdown]
# ## Задача. Продолжим исследование героев Dota2. Сгруппируйте по колонкам attack_type и primary_attr и выберите самый распространённый набор характеристик.

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
df.groupby([df.attack_type,df.primary_attr], as_index=False).size()
# Out:
#   attack_type primary_attr  size
# 0       Melee          agi    19
# 1       Melee          int     2
# 2       Melee          str    35
# 3      Ranged          agi    18
# 4      Ranged          int    40
# 5      Ranged          str     3

# %%
df.groupby(['attack_type', 'primary_attr']).agg({'id': 'count'}).sort_values('id', ascending=False)
# Out:
#                           id
# attack_type primary_attr
# Ranged      int           40
# Melee       str           35
#             agi           19
# Ranged      agi           18
#             str            3
# Melee       int            2

# %% [markdown]
# ## Задача Проведите группировку и примените метод, сохранив его в переменную mean_concentrations

# %%
df=pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
df
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %% [markdown]
# ## Задача Пользуясь предыдущими данными, укажите через пробел (без запятых) чему равны минимальная, средняя и максимальная концентрации аланина (alanin) среди видов рода Fucus. Округлите до 2-ого знака, десятичным разделителем является точка.

# %%
df.groupby([df.genus]).describe()
# Out:
#             sucrose                                                    \
#               count      mean       std       min       25%       50%
# genus
# Ascophyllum     1.0  6.825467       NaN  6.825467  6.825467  6.825467
# Cladophora      3.0  4.008792  1.634817  2.452623  3.157047  3.861470
# Fucus           3.0  4.355112  2.110570  3.001472  3.139171  3.276870
# Palmaria        1.0  0.704580       NaN  0.704580  0.704580  0.704580
# Saccharina      2.0  4.183596  3.602672  1.636122  2.909859  4.183596
#
#                                 alanin            ...   glucose            \
#                   75%       max  count      mean  ...       75%       max
# genus                                             ...
# Ascophyllum  6.825467  6.825467    1.0  0.875429  ...  3.414961  3.414961
# Cladophora   4.786877  5.712284    3.0  3.997055  ...  3.041936  3.343707
# Fucus        5.031933  6.786996    3.0  3.566411  ...  3.085842  3.623225
# ...

# %%
df['alanin'].groupby([df.genus]).describe()[['min','mean','max']].round(2).query("genus == 'Fucus'")
# Out:
#         min  mean   max
# genus
# Fucus  0.35  3.57  6.64

# %%
df.groupby('genus').agg({'alanin': ['min', 'mean', 'max']}).loc[['Fucus']].round(2)
# Out:
#       alanin
#          min  mean   max
# genus
# Fucus   0.35  3.57  6.64

# %% [markdown]
# ## Задача. Сгруппируйте данные по переменной group и соотнесите вопросы с ответами

# %%
df=pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
df
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
result = df.groupby(df.group)['sucrose'].agg(['max','min'])
result['diff'] = result['max']-result['min']
print(result[['diff']])
# Out:
#            diff
# group
# brown  5.189345
# green  3.259662
# red    0.000000

# %%
df.sucrose.groupby(df.group).describe()
# Out:
#        count      mean       std       min       25%      50%       75%  \
# group
# brown    6.0  4.709666  2.336471  1.636122  3.070321  5.00397  6.773014
# green    3.0  4.008792  1.634817  2.452623  3.157047  3.86147  4.786877
# red      1.0  0.704580       NaN  0.704580  0.704580  0.70458  0.704580
#
#             max
# group
# brown  6.825467
# green  5.712284
# red    0.704580

# %%
df.groupby('group') \
    .agg({'citrate': 'var', 'sucrose': lambda x: x.max() - x.min(), 'glucose': 'count'}) \
    .round(2)
# Out:
#        citrate  sucrose  glucose
# group
# brown     5.47     5.19        6
# green     3.95     3.26        3
# red        NaN     0.00        1

# %%
df.groupby('group').aggregate(['count', 'var', np.ptp])
# Out:
#       sucrose                     alanin                     citrate  \
#         count       var       ptp  count       var       ptp   count
# group
# brown       6  5.459098  5.189345      6  7.220351  6.294872       6
# green       3  2.672626  3.259662      3  7.059917  5.232574       3
# red         1       NaN  0.000000      1       NaN  0.000000       1
#
#                           glucose                     oleic_acid            \
#             var       ptp   count       var       ptp      count       var
# group
# brown  5.468942  5.351686       6  1.767756  3.740495          6  4.385233
# green  3.950113  3.857763       3  0.266265  1.026753          3  0.540388
# red         NaN  0.000000       1       NaN  0.000000          1       NaN
#
#
#             ptp
# group
# brown  6.100592
# green  1.396502
# red    0.000000

# %% [markdown]
# # ВИЗУАЛИЗАЦИЯ

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
df.columns = [x.replace(" ", "_") for x in students_performance.columns]

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.reading_score.hist()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='math_score',y='reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
ax=sns.lmplot(x='math_score',y='reading_score',data=df,fit_reg=False, hue='race/ethnicity' )
ax.set_xlabels('Math Score')
ax.set_ylabels('Reading Score')

# %% [markdown]
# ### Задача Представьте, что у вас есть датафрэйм df, хранящий данные о зарплате за месяц, со всего 1-ой колонкой income.Укажите верные способы, как отрисовать простой график зависимости зарплаты от даты

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
df.income.plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
plt.plot(df.index, df.income)

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df['income'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Вам дан датасэт с 2-мя фичами (колонками). Постройте график распределения точек (наблюдений) в пространстве этих 2-ух переменных (одна из них будет x, а другая - y) и напишите число кластеров, формируемых наблюдениями.В ответе вы должны указать число кластеров в виде числа (например: 3).
# ### ctrl+c ---> data=pd.read_clipboard()

# %%
#1
df=pd.read_csv('/Users/mkuzminetc/Downloads/dataset_209770_6.txt', sep=" ")

# %%
df
# Out:
#               x            y
# 0     85.516098   799.126204
# 1    801.750475   708.740119
# 2    512.542099  1391.061695
# 3    708.162157   399.819862
# 4    791.606211   702.620875
# ..          ...          ...
# 65   312.878487   102.529269
# 66    92.859026   792.517567
# 67   294.149580   120.107342
# 68  1099.821642   300.283137
# 69   298.156733    86.336533
#
# [70 rows x 2 columns]

# %%
df.plot.scatter(x='x',y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
#2
sns.scatterplot(df.x, df.y); #фак: ';' в конце - помогает не выводить адрес и характеристики графика
# Out:
# /Users/mkuzminetc/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)

g = sns.heatmap(df, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

plt.show()

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv')

# %%
df
# Out:
#   Unnamed: 0  species0  species1  species2  species3  species4
# 0   species0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1   species1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2   species2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3   species3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4   species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
# Step 0 - Read the dataset, calculate column correlations and make a seaborn heatmap

data = pd.read_csv('https://raw.githubusercontent.com/drazenz/heatmap/master/autos.clean.csv')

corr = data.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
data = pd.read_csv('https://raw.githubusercontent.com/drazenz/heatmap/master/autos.clean.csv')
data.head()
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                122  alfa-romero       gas        std
# 1           3                122  alfa-romero       gas        std
# 2           1                122  alfa-romero       gas        std
# 3           2                164         audi       gas        std
# 4           2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ## Задача нужно написать самое часто встречающееся КОЛИЧЕСТВО ролей у героя. Т.е у Anti-Mage их 3, у Axe их 4.

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
#вариант с циклом
length = [len(r.split(',')) for r in df.roles]
df['length'] = length

# %%
df.drop('role', axis=1,inplace=True)

# %%
#вариант без цикла
df['sum_roles'] = df.roles.str.split(',').str.len()

# %%
df.mode()
# Out:
#      Unnamed: 0 attack_type   id  legs      localized_name  \
# 0             0      Ranged    1   2.0             Abaddon
# 1             1         NaN    2   NaN           Alchemist
# 2             2         NaN    3   NaN  Ancient Apparition
# 3             3         NaN    4   NaN           Anti-Mage
# 4             4         NaN    5   NaN          Arc Warden
# ..          ...         ...  ...   ...                 ...
# 112         112         NaN  114   NaN          Windranger
# 113         113         NaN  119   NaN       Winter Wyvern
# 114         114         NaN  120   NaN        Witch Doctor
# 115         115         NaN  121   NaN         Wraith King
# 116         116         NaN  129   NaN                Zeus
#
#                                  name primary_attr  \
# 0               npc_dota_hero_abaddon          int
# 1     npc_dota_hero_abyssal_underlord          NaN
# 2             npc_dota_hero_alchemist          NaN
# ...

# %%
df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
df['length'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ЗАДАЧА Теперь перейдём к цветочкам. Магистрантка Адель решила изучить какие бывают ирисы. Помогите Адель узнать об ирисах больше - скачайте датасэт со значениями параметров ирисов, постройте их распределения и отметьте правильные утверждения, глядя на график.Распределение должно быть по всем образцам, без разделения на вид.Чтобы построить на 1-ом графике распределения для каждого из параметров, можно воспользоваться петлёй

# %%
iris=pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv',index_col=0)

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.distplot(iris, kde_kws={ "label":"sepal length"})
# Out:
# /Users/mkuzminetc/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# sns.distplot(датасет['название колонки'])
#for column in df:
    # Draw distribution with that column
#унимодальное - с одним горбом на линии тренда

#бимодальное - с двумя

#размах - дельта от минимального до максимального значения

for column in iris:
    sns.kdeplot(iris[str(column)])

# %%
sns.distplot(iris['petal width'], color = "blue")
sns.distplot(iris['petal length'], color ="green")
sns.distplot(iris['sepal width'], color = "yellow")
sns.distplot(iris['sepal length'], color = "orange")
# Out:
# /Users/mkuzminetc/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/mkuzminetc/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# рахмах
name = 'petal width'
print(iris[name].max() - iris[name].min())
# Out:
# 2.4

# %%
for column in iris.columns[0:4]:
    sns.distplot(iris[column], label=column)
plt.legend()
# Out:
# /Users/mkuzminetc/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/mkuzminetc/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.violinplot(data=iris["petal length"],orient='v', color="Purple")
# Out:
# <AxesSubplot:>

# %%
#Постройте его и посмотрите на scatter плоты для каждой из пар фичей. Какая из пар навскидку имеет наибольшую корреляцию?
sns.pairplot(iris, hue="species")

# %%
features = iris.columns
f,ax = plt.subplots(1,1)
sns.heatmap(iris[features].corr(), annot=True, square=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
iris.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
d = {'type': ['A', 'A', 'B', 'B'], 'value': [10, 14, 12, 23]}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %% [markdown]
# # Практические задания: Pandas

# %% [markdown]
# ## dataframe с именем my_stat сохранено 20 строк и четыре колонки (V1, V2, V3, V4):В переменную с именем subset_1 сохраните только первые 10 строк и только 1 и 3 колонку. В переменную с именем subset_2 сохраните все строки кроме 1 и 5 и только 2 и 4 колонку.

# %%
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')

# %%
df
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %%
subset_1=df[['V1','V3']].loc[0:9]

# %%
subset_2=df[['V2','V4']].drop([0, 4])

# %%
subset_2
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %% [markdown]
# ## Задача
# ## В переменную subset_1 сохраните только те наблюдения, у которых значения переменной V1  строго больше 0, и значение переменной V3  равняется 'A'.
# ## В переменную  subset_2  сохраните только те наблюдения, у которых значения переменной V2  не равняются 10, или значения переменной V4 больше или равно 1.

# %%
subset_1=df[(df["V1"]>0) & (df["V3"]=='A')]
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
subset_2=df[(df['V2']!=10)|(df['V4']>=1)]
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
# через query 
subset_1 = df.query("V1 > 0 & V3 == 'A'")
subset_2 = df.query("V4 >= 1 | V2 != 10")

# %%
subset_1
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %% [markdown]
# ## Теперь давайте преобразуем наши данные. В переменной my_stat лежат данные с которыми вам необходимо проделать следующее дейтвие. В этих данных (my_stat) создайте две новые переменных:
# ## V5 = V1 + V4, V6 = натуральный логарифм переменной V2

# %%
my_stat=pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')

# %%
my_stat["V5"]=my_stat["V1"]+my_stat["V4"]

# %%
#натуральный логарифм переменной V2
np.log(my_stat["V2"])
# Out:
# 0      2.564949
# 1      1.945910
# 2      2.397895
# 3      2.397895
# 4      2.302585
#          ...
# 495    2.079442
# 496    2.079442
# 497    2.397895
# 498    2.397895
# 499    2.079442
# Name: V2, Length: 500, dtype: float64

# %%
my_stat["V6"]=np.log(my_stat["V2"])

# %%
my_stat
# Out:
#      V1    V2 V3   V4   V5        V6
# 0     2  13.0  B  1.0  3.0  2.564949
# 1    -1   7.0  B  1.0  0.0  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895
# 4     0  10.0  B -1.0 -1.0  2.302585
# ..   ..   ... ..  ...  ...       ...
# 495   1   8.0  A -1.0  0.0  2.079442
# 496   3   8.0  A  1.0  4.0  2.079442
# 497  -1  11.0  B  2.0  1.0  2.397895
# 498   1  11.0  A  2.0  3.0  2.397895
# 499   0   8.0  B  1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
# альтернатичное решение
my_stat.eval('V5 = V1 + V4', inplace=True)
my_stat.eval('V6 = log(V2)', inplace=True)

#
my_stat['V5'] = my_stat.V1 + my_stat.V4
my_stat = my_stat.assign(V6=np.log(my_stat.V2))

# %% [markdown]
# ## Переименуйте колонки в данных  my_stat следующим образом:
# V1 -> session_value
# V2 -> group
# V3 -> time
# V4 -> n_users

# %%
my_stat.rename(columns={"V1": "session_value", "V2": "group", "V3": "time","V4": "n_users"}, inplace=True)

# %%
my_stat
# Out:
#      session_value  group time  n_users   V5        V6
# 0                2   13.0    B      1.0  3.0  2.564949
# 1               -1    7.0    B      1.0  0.0  1.945910
# 2                0   11.0    A      0.0  0.0  2.397895
# 3                2   11.0    A      2.0  4.0  2.397895
# 4                0   10.0    B     -1.0 -1.0  2.302585
# ..             ...    ...  ...      ...  ...       ...
# 495              1    8.0    A     -1.0  0.0  2.079442
# 496              3    8.0    A      1.0  4.0  2.079442
# 497             -1   11.0    B      2.0  1.0  2.397895
# 498              1   11.0    A      2.0  3.0  2.397895
# 499              0    8.0    B      1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
my_stat = my_stat.rename(columns={"V1": "session_value", "V2": "group", "V3": "time","V4": "n_users"})

# %%
#Jupyter устроен следующим образом - каждая ячейка после выполнения выдаёт output. 
#При таком переименовании, как в этом варианте, возвращается переименованный датафрэйм.
#Но исходный объект при этом никак не поменялся (достаточно вызвать my_stat в следующей ячейке, чтобы убедиться).
#Большинство методов датафрэймов возвращают новый датафрэйм по умолчанию. Параметр inplace, 
#позволяет изменять исходный объект (inplace=True). Иначе нужно писать
#df = df.rename(...)

# %%
# %timeit my_stat.columns = {'session_value':'V1', 'group':'V2', 'time':'V3', 'n_users':'V4'}
# %timeit my_stat.columns = ['session_value','group','time','n_users']
# %timeit my_stat.rename(columns={'V1': 'session_value', 'V2': 'group', 'V3': 'time', 
                                'V4': 'n_users'}, inplace=True)

# %% [markdown]
# ## И напоследок давайте разберемся, как заменять наблюдения в данных.В dataframe с именем my_stat сохранены данные с 4 колонками: session_value, group, time, n_users.
# ### 1. В переменной session_value замените все пропущенные значения на нули.
# ### 2. В переменной n_users замените все отрицательные значения на медианное значение переменной n_users (без учета отрицательных значений, разумеется).

# %%
my_stat=pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
#меняем вче NaN числа на 0
my_stat=my_stat.fillna(value=0)

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
my_stat['n_users'].median()
# Out:
# 3.5

# %%
#вычислить отрицательне числа в n_users
my_stat['n_users'][(my_stat['n_users']<=0)]
# Out:
# 1    -1
# 8   -11
# 9   -20
# Name: n_users, dtype: int64

# %%
med
# Out:
# 5.0

# %%
# вычисляем медиану для всех неотрицательных чисел
median=my_stat['n_users'][(my_stat["n_users"]>0)].median()

# %%
# заменяем все отрицательные числа в n_users на значения медианы неотри чисел из n_users
my_stat.loc[(my_stat['n_users']<0, 'n_users')] = median

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A        5
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B        5
# 9            0.0     9     A        5

# %%
#итог
#меняем вче NaN числа на 0
my_stat=my_stat.fillna(value=0)
# вычисляем медиану для всех неотрицательных чисел
median=my_stat['n_users'][(my_stat["n_users"]>0)].median()
# заменяем все отрицательные числа в n_users на значения медианы неотри чисел из n_users
my_stat.loc[(my_stat['n_users']<0, 'n_users')] = median

# %%
#албтернатива
import pandas as pd    
my_stat = my_stat.fillna(0)
my_stat.loc[my_stat.n_users<0, 'n_users']=my_stat.query("n_users>=0").n_users.median()

# %% [markdown]
# ### Задача В этой задаче для данных my_stat рассчитайте:
# ### 1. среднее значение переменной session_value для каждой группы (переменная group),
# ### 2. в получившемся dataframe  переменная group не должна превратиться в индекс.
# ### 4. Также переименуйте колонку со средним значением session_value в mean_session_value.
# ### 5. Получившийся результат сохраните в dataframe с именем mean_session_value_data.

# %%
mean_session_value_data=my_stat.groupby('group',as_index=False).agg({'session_value': 'mean'})

# %%
mean_session_value_data
# Out:
#   group  session_value
# 0     A            1.0
# 1     B            1.0

# %%
mean_session_value_data.rename(columns={"session_value": "mean_session_value"}, inplace=True)

# %%
mean_session_value_data
# Out:
#   group  mean_session_value
# 0     A                 1.0
# 1     B                 1.0

# %%
# можно и так без agg:
my_stat.groupby('group').n_users.count()
или так:
my_stat.groupby('group')['n_users'].count

# или так : 
mean_session_value_data = my_stat.groupby("group",as_index=False).session_value.agg({'mean_session_value':'mean'})
